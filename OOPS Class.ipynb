# %%
def hello(arg1,kyaBolnaHain,kiskoBolnaHai,kaiseBolnaHain):
    print(arg1)
    name = "DSA"
    kyaBolnaHain = 1
    kiskoBolnaHai = 2
    kaiseBolnaHain = 3
    print(name,)
    print("Hello Python")

# %%
l1.sort()

# %%
l1
# Out:
# [1, 2, 3]

# %%
hello(l1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 hello(l1)
#
# TypeError: hello() missing 3 required positional arguments: 'kyaBolnaHain', 'kiskoBolnaHai', and 'kaiseBolnaHain'

# %%
s1 = "Mayank"
hello(s1)

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
print(id(s1))
id
# Out:
# 4825002384
# <function id(obj, /)>

# %%
2 things
1. School
2. Number of Students

# %%
class Student:
    # class variables - not tied to any object (means instance of the class) but tied to the class itself
    # ye variables har object ke liye same rahenge. ye change nahi honge according to object
    # class vs instance variables - class variables are same for all objects, instance variables are different for each object
# instance variables - tied to the object (means instance of the class)
    # ye variables har object ke liye different rahenge. ye change honge according to object
    # instance vs class variables - instance variables are different for each object, class variables are same for all objects
 # instance variables are defined inside the __init__ method
 # class variables are defined outside the __init__ method
 # self - is a reference to the current object (means instance of the class)
    # self is used to access instance variables and methods of the class
    # self is used to differentiate between instance variables and class variables
    # self is used to call methods of the class

    # class variable are accessed using the class name like Student.schoolName
    # instance variable are accessed using the object name like s1.name
    # instance variable are defined inside the __init__ method using self like self.name = name
    # class variable are defined outside the __init__ method like schoolName = "MAPS"   
    



    numberOfStudents = 0
    schoolName = "MAPS"
    
    def __init__(self,name,rollNumber,marks):
        # print(id(self))
        self.rollNumber = rollNumber
        self.name = name
        self.marks = marks
        self.numberOfStudents  = Student.numberOfStudents + 1
        Student.numberOfStudents = Student.numberOfStudents + 1
        
    def study(self):
        print("I am "+ str(self.rollNumber) +" and I am  studying")
        
    def play(self):
        print("Pdh liya, now going to play")

# %%
s1 = Student("Mayank",1,90)

# %%
s2 = Student("Goku",2,50)

# %%
Student.schoolName
# Out:
# 'MAPS'

# %%
s1.numberOfStudents, s2.numberOfStudents
# Out:
# (1, 2)

# %%
Student("ABC",3,75)

# %%
s1.numberOfStudents
# Out:
# 1

# %%
s1.name,s1.rollNumber,s1.marks
# Out:
# ('Mayank', 1, 90)

# %%
s1.study()
# Out:
# I am 1 and I am  studying

# %%
print(id(s1))
# Out:
# 4824261584

# %%
s2 =Student("Goku",2,50)

# %%
s2.name,s2.rollNumber,s2.marks
# Out:
# ('Goku', 2, 50)

# %%
print(id(s1))
# Out:
# 4825002384

# %%
s1.
